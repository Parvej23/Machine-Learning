# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
df= pd.read_csv('car driving risk analysis.csv')

# %%
df
# Out:
#     speed  risk
# 0     200    95
# 1      90    20
# 2     300    98
# 3     110    60
# 4     240    72
# 5     115    10
# 6      50     7
# 7     230    85
# 8     190    45
# 9     260    91
# 10    290    82
# 11    185    59
# 12    310    93
# 13     95    18
# 14     30     2
